# %% [markdown]
# <a href="https://colab.research.google.com/github/SarkarPriyanshu/USHousingMarketAnalysis/blob/main/02_Understand_Data_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
# <div style="background-color: #E6E6DC; padding: 10px; color:#81A594">
#
# # Table of Contents
#
# 1. [UNDERSTANDING FEATURES](#understanding-features)
#     1. [Basic Analysis](#basic-analysis)
#     2. [EDA](#eda)
#     3. [Univariate Analysis](#univariate-analysis)
#         - [Univariate Analysis of Target column](#univariate-analysis-of-target-column)
#         - [Univariate Analysis of Independent Columns](#univariate-analysis-of-independent-columns)
#         - [Observation of Univariate Analysis](#observation-of-univariate-analysis)
#     4. [Multivariate Analysis](#multivariate-analysis)
#         - [Observation of Multivariate Analysis](#observation-of-multivariate-analysis)
#     5. [Feature Transformations](#feature-transformations)
#         - [Note: Skewness Interpretation](#note-skewness-interpretation)
#         - [Observation Of Feature Transformation](#observation-of-feature-transformation)
#
# </div>

# %% [markdown]
# # UNDERSTANDING FEATURES
#
# ### 1. CSUSHPISA (Target Feature):
#
# This index measures changes in the prices of residential properties in the United States. It provides an indication of the overall movement or trend in home prices over time.
#
# #### High Values (Rising Home Prices):
# **Pros:**
# - **Wealth Creation:**
#   - Increased home prices can make existing homeowners feel wealthier, potentially boosting consumer confidence and spending.
# - **Investment Growth:**
#   - Rising prices can attract real estate investors seeking profitable opportunities, leading to potential investment growth in the housing market.
#
# **Cons:**
# - **Housing Affordability Challenges:**
#   - Higher home prices can make it more challenging for first-time buyers to afford homes, reducing homeownership opportunities.
# - **Economic Imbalance:**
#   - Rapidly increasing prices might indicate an imbalanced or overheated housing market, leading to potential market instability or a bubble.
#
# #### Low Values (Falling Home Prices):
# **Pros:**
# - **Housing Affordability Improvements:**
#   - Lower home prices might make homeownership more accessible to buyers, potentially improving housing affordability.
# - **Market Entry Opportunities:**
#   - Falling prices can present opportunities for first-time buyers or those looking to upgrade, leading to increased market entry.
#
# **Cons:**
# - **Wealth Reduction:**
#   - Declining home prices might reduce the perceived wealth of homeowners, potentially impacting consumer confidence and spending.
# - **Investment Caution:**
#   - Investors might become cautious about real estate investments during periods of falling prices, potentially slowing investment in the market.
#
# #### Overall Impact:
# - **Consumer Spending:**
#   - High values can boost consumer spending due to increased wealth, while low values might lead to caution or reduced spending.
# - **Construction Industry:**
#   - High values might encourage more construction activity, while low values might slow down construction as builders react to market conditions.
# - **Mortgage Market:**
#   - High values might encourage lending but also tighten lending standards, while low values might prompt lenders to ease requirements to stimulate demand.
#
#
#
# ### 2. EVACANTUSQ176N (Housing Inventory Estimate: Vacant Housing Units in the United States):
#
# This estimates the number of vacant housing units across the United States. It gives an idea of the available housing that is not currently occupied.
#
# #### High Values (More Vacant Houses):
# **Pros:**
# - **Rental Market Opportunities:**
#   - More vacant houses can offer increased rental options for people looking to rent homes, potentially providing more choices at different price points.
# - **Potential Investment Opportunities:**
#   - Real estate investors might find opportunities to purchase and renovate vacant houses, contributing to revitalization efforts and potentially increasing property values in those areas.
#
# **Cons:**
# - **Economic Slowdown Indication:**
#   - High levels of vacant houses might indicate an oversupply relative to demand, which could suggest economic slowdown or instability in the housing market.
# - **Neighborhood Challenges:**
#   - Concentrated vacant houses in neighborhoods might attract issues like vandalism, reduced property values, and a decline in community livability.
#
# #### Low Values (Fewer Vacant Houses):
# **Pros:**
# - **Stable Housing Demand:**
#   - Fewer vacant houses might indicate a strong demand for housing, potentially suggesting a robust and stable housing market.
# - **Community Stability:**
#   - Lower levels of vacant houses could contribute to a more vibrant and stable neighborhood environment, enhancing community cohesion.
#
# **Cons:**
# - **Housing Affordability Challenges:**
#   - Lower levels of vacant houses might lead to increased competition among buyers, potentially driving up prices and making it harder for some to afford homes.
# - **Limited Rental Availability:**
#   - Limited vacant houses might reduce rental options, making it harder for renters to find suitable properties or driving rental prices higher.
#
#
#
# ### 3. GDP (Gross Domestic Product):
# Measures the total value of goods and services produced in the US. A growing GDP usually indicates a healthy economy, potentially leading to higher incomes and increased housing demand.
#
# #### High GDP:
# **Pros:**
# - **Job Creation and Low Unemployment:**
#   - High GDP often correlates with more job opportunities and lower unemployment rates, as businesses expand to meet demand.
# - **Increased Consumer Spending:**
#   - Higher GDP can lead to higher incomes for people, potentially increasing spending on goods and services, contributing to economic growth.
# - **Investment Opportunities:**
#   - A thriving economy with high GDP may attract more investments due to the perceived stability and potential for profit.
#
# **Cons:**
# - **Inflationary Pressure:**
#   - High GDP can sometimes lead to increased demand for goods and services, potentially causing inflation if supply cannot keep up.
# - **Environmental Impact:**
#   - Rapid economic growth associated with high GDP may lead to increased environmental concerns such as pollution and resource depletion.
#
# #### Low GDP:
# **Pros:**
# - **Economic Stimulus and Innovation:**
#   - During periods of low GDP, governments and businesses might focus on stimulating the economy through innovation and new policies to improve economic conditions.
# - **Environmental Benefits:**
#   - Lower economic activity during periods of low GDP might lead to reduced environmental impact, giving time for conservation efforts.
#
# **Cons:**
# - **Job Losses and High Unemployment:**
#   - Low GDP can result in job losses as businesses struggle, leading to higher unemployment rates and reduced incomes.
# - **Reduced Consumer Confidence:**
#   - Low GDP may affect consumer confidence, leading to reduced spending and investment, which can further slow economic growth.
#
#
#
# ### 4. INTDSRUSM193N (Interest Rates, Discount Rate for United States):
# Indicates the interest rates or discount rates in the United States. Higher rates can potentially reduce affordability and decrease demand for borrowing, impacting home buying activity.
#
# #### High Interest Rates:
# **Pros:**
# - **Savings Incentive:**
#   - Higher rates encourage saving as people earn more interest on their savings, which can increase funds available for investments.
# - **Currency Strength:**
#   - Higher rates might attract foreign investment, leading to stronger demand for the country's currency.
#
# **Cons:**
# - **Borrowing Becomes Costly:**
#   - High rates make borrowing expensive, reducing spending on items like homes, cars, and business investments.
# - **Economic Slowdown:**
#   - Businesses and consumers might delay spending and investments due to higher borrowing costs, potentially leading to an economic slowdown.
#
# #### Low Interest Rates:
# **Pros:**
# - **Borrowing Becomes Affordable:**
#   - Lower rates make borrowing cheaper, encouraging spending and investment in homes, businesses, and consumer goods.
# - **Economic Stimulus:**
#   - Low rates can stimulate economic growth as people and businesses are encouraged to borrow and spend.
#
# **Cons:**
# - **Savings Challenge:**
#   - Lower rates might discourage saving as the return on savings is low, potentially reducing funds available for investments.
# - **Asset Price Inflation:**
#   - Low rates might lead to inflated asset prices like real estate or stocks, creating market bubbles and potential instability.
#
# #### Overall Impact:
# - **Consumer Spending and Investment:**
#   - High rates may limit spending and investment, while low rates may encourage more borrowing and spending.
# - **Business Growth:**
#   - High rates may hinder business expansions, while low rates may encourage investment in growth opportunities.
# - **Currency and Global Investments:**
#   - High rates might attract foreign investment, strengthening the currency, while low rates might encourage investments abroad.
#
#
# ### 5. MSACSR (Monthly Supply of New Houses in the United States):
#
# This metric measures the monthly supply of new houses across the entire United States, indicating the number of new houses available in the market.
#
# #### High MSACSR (More New Houses):
# **Pros:**
# - **Increased Housing Availability:**
#   - More new houses mean more options for people looking to buy or rent homes, potentially improving housing availability.
# - **Construction Industry Growth:**
#   - Higher supply can boost the construction sector, leading to job creation and economic growth.
#
# **Cons:**
# - **Market Saturation Risk:**
#   - Too many new houses might saturate the market, leading to excess supply, potential price drops, and reduced profitability for builders.
# - **Economic Imbalance:**
#   - Oversupply might signal an imbalance between supply and demand, potentially leading to a slowdown in construction activity.
#
# #### Low MSACSR (Fewer New Houses):
# **Pros:**
# - **Market Stability:**
#   - Limited supply might help maintain market stability, preventing excessive fluctuations in prices.
# - **Increased Demand Impact:**
#   - Low supply might create stronger demand, potentially increasing property values and profitability for builders.
#
# **Cons:**
# - **Limited Housing Options:**
#   - Fewer new houses might limit choices for buyers or renters, potentially leading to increased competition and higher prices.
# - **Construction Sector Challenges:**
#   - Reduced supply might hinder growth in the construction sector, affecting job creation and economic expansion.
#
# #### Overall Impact:
# - **Housing Affordability:**
#   - High supply might improve affordability, while low supply might lead to increased prices due to high demand.
# - **Construction Industry:**
#   - High supply can benefit the construction sector, while low supply might hinder its growth.
# - **Market Stability:**
#   - Maintaining a balanced supply might contribute to market stability, preventing excessive price fluctuations.
#
#
#
# ### 6. PERMIT (New Privately-Owned Housing Units Authorized in Permit-Issuing Places):
#
# This metric measures the number of new housing units authorized by permits in specific areas, indicating the planned construction of new homes in a given area.
#
# #### High Number of Permits:
# **Pros:**
# - **Economic Growth and Construction Activity:**
#   - High permits suggest increased construction activity, creating jobs and contributing to economic growth.
# - **Housing Availability and Options:**
#   - More permits mean more new houses available for people to buy or rent, providing more housing options.
#
# **Cons:**
# - **Potential Oversupply:**
#   - Too many permits might lead to an oversupply of houses, potentially causing a drop in property prices.
# - **Market Volatility Risk:**
#   - Excessive permits could signal market instability if there's a mismatch between supply and demand.
#
# #### Low Number of Permits:
# **Pros:**
# - **Market Stability:**
#   - Limited permits might stabilize the housing market, preventing oversupply and maintaining property values.
# - **Price Stability:**
#   - Fewer permits might keep property prices stable, preventing rapid price fluctuations.
#
# **Cons:**
# - **Housing Shortage Potential:**
#   - Fewer permits might lead to a shortage of available homes, limiting choices for buyers or renters.
# - **Construction Slowdown:**
#   - Reduced permits might slow down construction activity, impacting job creation and economic growth in the construction sector.
#
# #### Overall Impact:
# - **Housing Affordability:**
#   - High permits might increase housing supply and affordability, while low permits might affect affordability due to limited supply.
# - **Economic Growth:**
#   - High permits can stimulate economic growth, while low permits might hinder growth in the construction industry.
# - **Market Stability:**
#   - Balancing permits to match demand is crucial to prevent market volatility and maintain stable property prices.
#
#
#
# ### 7. UMCSENT (University of Michigan: Consumer Sentiment):
#
# Reflects consumer sentiment or confidence about the economy and their financial situation. Higher consumer sentiment often correlates with increased willingness to make major purchases, including homes.
#
# #### High Consumer Sentiment:
# **Pros:**
# - **Increased Spending:**
#   - High sentiment can lead to increased consumer spending as people feel more confident about the economy and their financial situations.
# - **Economic Growth:**
#   - High sentiment can stimulate economic growth as increased spending boosts demand for goods and services.
#
# **Cons:**
# - **Inflationary Pressure:**
#   - High sentiment might lead to increased demand, potentially causing inflation if supply cannot keep up.
# - **Over-Optimism Risks:**
#   - Excessively high sentiment might lead to over-optimism, potentially causing people to take on too much debt or overspend.
#
# #### Low Consumer Sentiment:
# **Pros:**
# - **Savings and Caution:**
#   - Low sentiment might lead to increased savings as people become more cautious about their spending.
# - **Price Stability:**
#   - Lower sentiment might moderate demand, preventing rapid price increases and promoting price stability.
#
# **Cons:**
# - **Reduced Spending:**
#   - Low sentiment can lead to reduced consumer spending, potentially slowing down economic growth.
# - **Economic Downturn Concerns:**
#   - Prolonged low sentiment might indicate concerns about the economy, potentially leading to decreased business investments and economic downturns.
#
# #### Overall Impact:
# - **Consumer Behavior:**
#   - High sentiment might boost spending and economic growth, while low sentiment might lead to cautious spending and potential economic slowdowns.
# - **Business Decisions:**
#   - High sentiment might encourage businesses to invest and expand, while low sentiment might lead to businesses being more cautious about expansion plans.
# - **Market Stability:**
#   - Maintaining balanced sentiment is crucial to prevent excessive fluctuations in spending and economic stability.
#
# ### 8. UMCSENT (University of Michigan: Consumer Sentiment):
#
# Reflects consumer sentiment or confidence about the economy and their financial situation. Higher consumer sentiment often correlates with increased willingness to make major purchases, including homes.
#
# #### High Consumer Sentiment:
# **Pros:**
# - **Increased Spending:**
#   - High sentiment can lead to increased consumer spending as people feel more confident about the economy and their financial situations.
# - **Economic Growth:**
#   - High sentiment can stimulate economic growth as increased spending boosts demand for goods and services.
#
# **Cons:**
# - **Inflationary Pressure:**
#   - High sentiment might lead to increased demand, potentially causing inflation if supply cannot keep up.
# - **Over-Optimism Risks:**
#   - Excessively high sentiment might lead to over-optimism, potentially causing people to take on too much debt or overspend.
#
# #### Low Consumer Sentiment:
# **Pros:**
# - **Savings and Caution:**
#   - Low sentiment might lead to increased savings as people become more cautious about their spending.
# - **Price Stability:**
#   - Lower sentiment might moderate demand, preventing rapid price increases and promoting price stability.
#
# **Cons:**
# - **Reduced Spending:**
#   - Low sentiment can lead to reduced consumer spending, potentially slowing down economic growth.
# - **Economic Downturn Concerns:**
#   - Prolonged low sentiment might indicate concerns about the economy, potentially leading to decreased business investments and economic downturns.
#
# #### Overall Impact:
# - **Consumer Behavior:**
#   - High sentiment might boost spending and economic growth, while low sentiment might lead to cautious spending and potential economic slowdowns.
# - **Business Decisions:**
#   - High sentiment might encourage businesses to invest and expand, while low sentiment might lead to businesses being more cautious about expansion plans.
# - **Market Stability:**
#   - Maintaining balanced sentiment is crucial to prevent excessive fluctuations in spending and economic stability.
#
#
# ### 9. MSPUS (Higher House Prices):
# **Pros:**
# - **Wealth Creation:**
#   - *Pro:* High prices can make homeowners feel wealthier, potentially increasing consumer spending.
# - **Investment Opportunities:**
#   - *Pro:* Higher prices might attract real estate investors seeking profitable opportunities.
#
# **Cons:**
# - **Housing Affordability:**
#   - *Con:* High prices can make it harder for some people to afford homes, potentially reducing homeownership rates.
# - **Market Instability Risk:**
#   - *Con:* Rapid price increases might indicate an overheated market, potentially leading to market corrections or instability.
#
# ### Low MSPUS (Lower House Prices):
# **Pros:**
# - **Housing Affordability:**
#   - *Pro:* Lower prices can make homeownership more accessible to buyers, potentially increasing homeownership rates.
# - **Market Entry Opportunities:**
#   - *Pro:* Lower prices might present opportunities for first-time buyers or those looking to upgrade.
#
# **Cons:**
# - **Wealth Reduction:**
#   - *Con:* Declining prices might reduce the perceived wealth of homeowners, potentially impacting consumer spending.
# - **Investment Caution:**
#   - *Con:* Investors might be cautious about real estate investments during periods of falling prices, potentially reducing investment in the market.
#
# ### Overall Impact:
# - **Consumer Spending:**
#   - High prices might boost consumer spending due to increased wealth, while low prices might lead to caution or reduced spending.
# - **Housing Market Dynamics:**
#   - High or low prices can impact the number of home sales and the overall health of the real estate market.
# - **Affordability and Market Stability:**
#   - Balancing prices to ensure affordability and market stability is crucial for a healthy housing market.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Basic Analysis

# %%
df = pd.read_csv('/content/USHousing',parse_dates=['DATE']).iloc[:,1:]

# %%
df.set_index(df['DATE'],inplace=True)

# %%
df.drop('DATE',axis=1,inplace=True)

# %%
df.shape
# Out:
# (86, 8)

# %%
df.sample(5)
# Out:
#             CSUSHPISA  EVACANTUSQ176N        GDP  INTDSRUSM193N  MSACSR  \
# DATE
# 2011-01-01    141.521         18998.0  15351.448           0.75     7.3
# 2020-01-01    214.994         15967.0  21706.513           2.25     5.7
# 2015-10-01    174.792         17288.0  18435.137           0.75     5.6
# 2014-07-01    164.579         18170.0  17804.228           0.75     6.2
# 2014-10-01    166.641         16956.0  17912.079           0.75     5.3
#
#             PERMIT  UMCSENT     MSPUS
# DATE
# 2011-01-01   576.0     74.2  226900.0
# 2020-01-01  1500.0     99.8  329000.0
# 2015-10-01  1160.0     90.0  302500.0
# 2014-07-01  1076.0     81.8  281000.0
# 2014-10-01  1094.0     86.9  298900.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86 entries, 2000-04-01 to 2021-07-01
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CSUSHPISA       86 non-null     float64
#  1   EVACANTUSQ176N  86 non-null     float64
#  2   GDP             86 non-null     float64
#  3   INTDSRUSM193N   86 non-null     float64
#  4   MSACSR          86 non-null     float64
#  5   PERMIT          86 non-null     float64
#  6   UMCSENT         86 non-null     float64
#  7   MSPUS           86 non-null     float64
# dtypes: float64(8)
# memory usage: 6.0 KB

# %%
df.isnull().sum()
# Out:
# CSUSHPISA         0
# EVACANTUSQ176N    0
# GDP               0
# INTDSRUSM193N     0
# MSACSR            0
# PERMIT            0
# UMCSENT           0
# MSPUS             0
# dtype: int64

# %%
df.describe()
# Out:
#         CSUSHPISA  EVACANTUSQ176N           GDP  INTDSRUSM193N     MSACSR  \
# count   86.000000       86.000000     86.000000      86.000000  86.000000
# mean   164.951628    16846.872093  15932.409047       2.120000   5.770930
# std     33.818778     1636.179789   3667.466889       1.832632   1.916238
# min    102.922000    13268.000000  10247.720000       0.250000   3.300000
# 25%    141.651750    15656.250000  13188.032500       0.750000   4.300000
# 50%    163.479500    17190.500000  15330.461000       1.250000   5.300000
# 75%    183.612000    18175.250000  18665.259750       2.937500   6.700000
# max    262.707000    19137.000000  23828.973000       6.250000  12.200000
#
#             PERMIT     UMCSENT          MSPUS
# count    86.000000   86.000000      86.000000
# mean   1326.151163   85.259302  256053.488372
# std     474.493898   12.113390   56174.615782
# min     521.000000   57.600000  163200.000000
# 25%    1009.000000   75.350000  219850.000000
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariant Analysis

# %% [markdown]
# ### Univariant Analysis of Target column

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Prices Index of Residential Properties in US Over Years')
ax.plot(df.index, df['CSUSHPISA'])
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')
plt.show()

# %% [markdown]
# - There is sudden drop after 2008 and it deep on declining
# till 2012
# - Financial firms sold these subprime loans to large commercial investors in pools of mortgages known as mortgage-backed securities.
# - By the fall of 2008, borrowers were defaulting on subprime mortgages in high numbers; the collapse of the financial markets and the global Great Recession ensued.
# Source : https://www.investopedia.com/articles/economics/09/subprime-market-2008.asp

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for CSUSHPISA feature',fontsize=20)
sns.distplot(df['CSUSHPISA'],ax=ax[0])
sns.boxplot(df['CSUSHPISA'],ax=ax[1])
plt.show()

# %%
IQR = (df['CSUSHPISA'].quantile(0.75)-df['CSUSHPISA'].quantile(0.25))
df.loc[df['CSUSHPISA'] > (df['CSUSHPISA'].quantile(0.75) + 1.5 * IQR)]
# Out:
#             CSUSHPISA  EVACANTUSQ176N        GDP  INTDSRUSM193N  MSACSR  \
# DATE
# 2021-04-01    249.055         15657.0  23292.362           0.25     4.7
# 2021-07-01    262.707         15208.0  23828.973           0.25     5.7
#
#             PERMIT  UMCSENT     MSPUS
# DATE
# 2021-04-01  1714.0     88.3  382600.0
# 2021-07-01  1618.0     81.2  411200.0

# %% [markdown]
# - Two observations `2021-04-01` and `2021-07-01` are extreme value after investigation we come to know that this is due to hight `GDP` and `PERMIT` and Lower in `INTDSRUSM193N` that lead to higher `CSUSHPISA` factors
#
#
# - Higher value of `Gross Domestic Product (GDP)` lead to higher incomes for people, Increased Consumer Spending, high GDP may attract more investments due to the perceived stability and potential for profit.`
# U.S. gdp for 2021 was $23,315.08B, a 10.71% increase from 2020.`
#
# - Higher value of `New Privately-Owned Housing Units Authorized in Permit-Issuing Places (PERMIT)` lead to Housing Availability and Options, for people to buy or rent.
#
# - Lower value of `INTDSRUSM193N (Interest Rates, Discount Rate for United States)` lead to increase funds available for investments.
#
# - This all factor are responsible for very high `CSUSHPISA` values this factors can't be removed or treated as outliers.

# %% [markdown]
# ### Univariant Analysis of Independent Columns

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Vacant Housing Units in US Over Years')
ax.plot(df.index, df['EVACANTUSQ176N'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Vacant Housing Units (Thousands)')
ax.set_ylim(0, max(df['EVACANTUSQ176N'])+1000)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for EVACANTUSQ176N feature',fontsize=20)
sns.distplot(df['EVACANTUSQ176N'],ax=ax[0])
sns.boxplot(df['EVACANTUSQ176N'],ax=ax[1])
plt.show()

# %% [markdown]
# - There is constant growth of Vacant Housing Units in US after 2004 and we can assume that due to pandamic there is a sudden drop after 2020 but then it get back to its normal flow after that period of time
#
# - Skewed toward left distribution defines over a course of years there is very small period of time where Vacant Housing Units in US was low and very high number of time where Vacant Housing Units in US was high.
#
# - No extreme values

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Gross Domestic Product of US Over Years')
ax.plot(df.index, df['GDP'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Gross Domestic Product (Billions of Dollars)')
ax.set_ylim(0, max(df['GDP'])+1000)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for GDP feature',fontsize=20)
sns.distplot(df['GDP'],ax=ax[0])
sns.boxplot(df['GDP'],ax=ax[1])
plt.show()

# %% [markdown]
# - The Gross Domestic Product for US over years is constantly increasing as we can see in lineplot except a small drop near 2020 due to pandamic.
# - Almost normal distribution
# - No outlier/extreme values

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Interest Rates, Discount Rate for United States Over Years')
ax.plot(df.index, df['INTDSRUSM193N'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Interest Rates, Discount Rate')
ax.set_ylim(0, max(df['INTDSRUSM193N'])+1)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for INTDSRUSM193N feature',fontsize=20)
sns.distplot(df['INTDSRUSM193N'],ax=ax[0])
sns.boxplot(df['INTDSRUSM193N'],ax=ax[1])
plt.show()

# %%
IQR = (df['INTDSRUSM193N'].quantile(0.75)-df['INTDSRUSM193N'].quantile(0.25))
df.loc[df['INTDSRUSM193N'] > (df['INTDSRUSM193N'].quantile(0.75) + 1.5 * IQR)]
# Out:
#             CSUSHPISA  EVACANTUSQ176N        GDP  INTDSRUSM193N  MSACSR  \
# DATE
# 2006-07-01    183.068         16769.0  13870.188           6.25     7.3
# 2006-10-01    183.198         16894.0  14039.560           6.25     7.3
# 2007-01-01    184.517         17724.0  14215.651           6.25     7.2
# 2007-04-01    183.010         17547.0  14402.082           6.25     7.4
# 2007-07-01    179.111         18049.0  14564.117           6.25     8.3
#
#             PERMIT  UMCSENT     MSPUS
# DATE
# 2006-07-01  1763.0     84.7  235600.0
# 2006-10-01  1570.0     93.6  245400.0
# 2007-01-01  1626.0     96.9  257400.0
# 2007-04-01  1470.0     87.1  242200.0
# 2007-07-01  1361.0     90.4  241800.0

# %% [markdown]
# - This was the major reason of sudden hick in Interest rate in US source : https://www.investopedia.com/articles/economics/09/financial-crisis-review.asp
# same trend so after 2016 to 2020
#
# - We can't remove them from our data.

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Monthly Supply of New Houses in United States Over Years')
ax.plot(df.index, df['MSACSR'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Monthly Supply')
ax.set_ylim(0, max(df['MSACSR']+2))
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for MSACSR feature',fontsize=20)
sns.distplot(df['MSACSR'],ax=ax[0])
sns.boxplot(df['MSACSR'],ax=ax[1])
plt.show()

# %%
IQR = (df['MSACSR'].quantile(0.75)-df['MSACSR'].quantile(0.25))
df.loc[df['MSACSR'] > (df['MSACSR'].quantile(0.75) + 1.5 * IQR)]
# Out:
#             CSUSHPISA  EVACANTUSQ176N        GDP  INTDSRUSM193N  MSACSR  \
# DATE
# 2008-07-01    163.566         18651.0  14898.999           2.25    10.5
# 2008-10-01    158.327         18973.0  14608.209           1.25    11.6
# 2009-01-01    151.507         19137.0  14430.902           0.50    12.2
# 2009-04-01    147.949         18752.0  14381.236           0.50    10.7
#
#             PERMIT  UMCSENT     MSPUS
# DATE
# 2008-07-01   921.0     61.2  226500.0
# 2008-10-01   736.0     57.6  222500.0
# 2009-01-01   545.0     61.2  208400.0
# 2009-04-01   521.0     65.1  220900.0

# %% [markdown]
# - Right Skewed distribution
# - Outliers but genuen observations we can't remove them

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('New Privately-Owned Housing Units Authorized in Permit-Issuing Places Over Years')
ax.plot(df.index, df['PERMIT'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Permit-Issuing (Thousands)')
ax.set_ylim(0, max(df['PERMIT'])+50)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for PERMIT feature',fontsize=20)
sns.distplot(df['PERMIT'],ax=ax[0])
sns.boxplot(df['PERMIT'],ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Consumer Sentiment Over Years')
ax.plot(df.index, df['UMCSENT'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Consumer Sentiment')
ax.set_ylim(0, max(df['UMCSENT'])+10)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for UMCSENT feature',fontsize=20)
sns.distplot(df['UMCSENT'],ax=ax[0])
sns.boxplot(df['UMCSENT'],ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.set_title('Median Sales Price of Houses Sold for US over Years')
ax.plot(df.index, df['MSPUS'])
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Median Sales Price')
ax.set_ylim(0, max(df['MSPUS'])+10000)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Distribution and Boxplot for MSPUS feature',fontsize=20)
sns.distplot(df['MSPUS'],ax=ax[0])
sns.boxplot(df['MSPUS'],ax=ax[1])
plt.show()

# %% [markdown]
# ### Observation of Univariant Analysis
#   - All features are sort of Normal distribution few are skewed but as per investigation they are all genuen and that lead to outliers but we have to include those features.
#
#   - As we saw earlier we have 0 null values.
#   - Try different Transformations to handle skewed feature with outliers.
#   - We also notice that few of the independent columns are affecting other independent feature lead to multicolinearity bit they are all genuene and can be used for model building.

# %% [markdown]
# ## Multi-variant Analysis

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Vacant Housing Units in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['EVACANTUSQ176N'],color='darkgoldenrod',label='Vacant Housing Units ')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Vacant Housing Units (Thousands)')
ax2.set_ylim(0, max(df['EVACANTUSQ176N'])+1000)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Vacant Housing Units in US Over Years')
ax[0].scatter(df['EVACANTUSQ176N'], df['CSUSHPISA'])
ax[0].set_xlabel('Vacant Housing Units (Thousands)')
ax[0].set_ylabel('Prices Index (Seasonally Adjusted)')

sns.regplot(data=df,x=df['EVACANTUSQ176N'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Vacant Housing Units (Thousands)')
ax[1].set_ylabel('Prices Index (Seasonally Adjusted)')
plt.show()

# %% [markdown]
# - We can see there is sort of inverse relationship between Price index and Vacant House Unit if we see behavior pattern between 2007 to 2019.
#
# - Although if we see the scatter and regplot we can say they are no linear correlation between House Price Index and Vacant House Units.

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Gross Domestic Product in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['GDP'],color='darkgoldenrod',label='Gross Domestic Product ')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('GDP (Billions of Dollars)')
ax2.set_ylim(0, max(df['GDP'])+1000)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs GDP in US Over Years')
ax[0].scatter(df['GDP'], df['CSUSHPISA'])
ax[0].set_xlabel('GDP (Billions of Dollars)')
ax[0].set_ylabel('Prices Index (Seasonally Adjusted)')

sns.regplot(data=df,x=df['GDP'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('GDP (Billions of Dollars)')
ax[1].set_ylabel('Prices Index (Seasonally Adjusted)')
plt.show()

# %% [markdown]
# -  There is sort of linear correlation between GDP and Price Index as we can see in regplot.
# - Although there is no causation we can clearly see in line plot even gdp is constantly growing despite of price index is declining and rising over course of period.

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Interest Rates, Discount Rate  in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['INTDSRUSM193N'],color='darkgoldenrod',label='Interest Rates, Discount Rate')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Interest Rates, Discount Rate ')
ax2.set_ylim(0, max(df['INTDSRUSM193N'])+2)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs GDP in US Over Years')
ax[0].scatter(df['INTDSRUSM193N'], df['CSUSHPISA'])
ax[0].set_xlabel('Interest Rates, Discount Rate')
ax[0].set_ylabel('Prices Index (Seasonally Adjusted)')

sns.regplot(data=df,x=df['INTDSRUSM193N'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Interest Rates, Discount Rate')
ax[1].set_ylabel('Prices Index (Seasonally Adjusted)')
plt.show()

# %% [markdown]
# - Well we can clearly see on all the above plots there is no relation between Interest Rate and Price Index
# - We deal with this column in feature selection stage

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Monthly Supply of New Houses in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['MSACSR'],color='darkgoldenrod',label='Monthly Supply of New Houses')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Monthly Supply of New Houses ')
ax2.set_ylim(0, max(df['MSACSR'])+2)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs GDP in US Over Years')
ax[0].scatter(df['MSACSR'], df['CSUSHPISA'])
ax[0].set_xlabel('Interest Rates, Discount Rate')
ax[0].set_ylabel('Monthly Supply of New Houses')

sns.regplot(data=df,x=df['MSACSR'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Interest Rates, Discount Rate')
ax[1].set_ylabel('Monthly Supply of New Houses')
plt.show()

# %% [markdown]
# - Too many new houses might saturate the market, leading to excess supply, potential price drops, and reduced profitability for builders during 2007.

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Permit-Issuing Places in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['PERMIT'],color='darkgoldenrod',label='Permit-Issuing Places')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Permit-Issuing Places ')
ax2.set_ylim(0, max(df['PERMIT'])+50)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs GDP in US Over Years')
ax[0].scatter(df['PERMIT'], df['CSUSHPISA'])
ax[0].set_xlabel('Permit-Issuing Places')
ax[0].set_ylabel('Monthly Supply of New Houses')

sns.regplot(data=df,x=df['PERMIT'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Permit-Issuing Places')
ax[1].set_ylabel('Monthly Supply of New Houses')
plt.show()

# %% [markdown]
# - No linear correlation found
# - There we sudden drop due to crises of 2007 but wont affect price index as we can see in line plot

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Surveys of Consumers in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['UMCSENT'],color='darkgoldenrod',label='Surveys of Consumers')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Surveys of Consumers ')
ax2.set_ylim(0, max(df['UMCSENT'])+50)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Surveys of Consumers  in US Over Years')
ax[0].scatter(df['UMCSENT'], df['CSUSHPISA'])
ax[0].set_xlabel('Permit-Issuing Places')
ax[0].set_ylabel('Surveys of Consumers')

sns.regplot(data=df,x=df['UMCSENT'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Permit-Issuing Places')
ax[1].set_ylabel('Surveys of Consumers')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Median Sales Price in US Over Years')
ax.plot(df.index, df['CSUSHPISA'],color='burlywood',label='Prices Index')
ax.axvline(pd.to_datetime('2007'), color='olive', linestyle='-.',alpha=0.5)  # Vertical line at 2007
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Prices Index (Seasonally Adjusted)')
ax.set_ylim(0, max(df['CSUSHPISA'])+50)
ax.text(pd.to_datetime('2007'), df['CSUSHPISA'].mean(), '2007 Financial Crisis', color='red', ha='right')

ax2 = ax.twinx()
ax2.plot(df.index, df['MSPUS'],color='darkgoldenrod',label='Median Sales Price')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Median Sales Price')
ax2.set_ylim(0, max(df['MSPUS'])+50)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(20,5))
fig.suptitle('Prices Index of Residential Properties vs Median Sales Price  in US Over Years')
ax[0].scatter(df['MSPUS'], df['CSUSHPISA'])
ax[0].set_xlabel('Permit-Issuing Places')
ax[0].set_ylabel('Median Sales Price')

sns.regplot(data=df,x=df['MSPUS'],y=df['CSUSHPISA'],ax=ax[1])
ax[1].set_xlabel('Permit-Issuing Places')
ax[1].set_ylabel('Median Sales Price')
plt.show()

# %% [markdown]
# - There is good linear correlation between median sales and Price Index

# %%
realtional_df =  df.groupby(df.index.year).agg(
    CSUSHPISA_mean = ('CSUSHPISA','mean'),
    EVACANTUSQ176N_sum = ('EVACANTUSQ176N','sum'),
    GDP_mean = ('GDP','mean'),
    MSPUS_mean = ('MSPUS','mean')
)

# %%
realtional_df.sample(5)
# Out:
#       CSUSHPISA_mean  EVACANTUSQ176N_sum      GDP_mean     MSPUS_mean
# DATE
# 2021      250.440333             46467.0  23240.506667  387866.666667
# 2010      145.330250             75632.0  15048.971000  222700.000000
# 2017      190.446000             69519.0  19612.102500  322425.000000
# 2008      165.840750             74967.0  14769.861750  229550.000000
# 2000      105.119333             40627.0  10333.876333  168300.000000

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Average Prices Index vs Sum Vacant Housing Units in US Per Years')
ax.plot(realtional_df.index, realtional_df['CSUSHPISA_mean'],marker='o',color='darkgoldenrod',label='Prices Index')
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Average Prices Index')

ax2 = ax.twinx()
ax2.bar(realtional_df.index, realtional_df['EVACANTUSQ176N_sum'],color='burlywood',label='Sum Vacant Housing',alpha=0.8)
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Sum Vacant Housing Units')
ax2.set_ylim(0, max(realtional_df['EVACANTUSQ176N_sum'])+1000)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Average Prices Index vs Average Gross Domastic Product in US Per Years')
ax.bar(realtional_df.index, realtional_df['CSUSHPISA_mean'],color='burlywood',label='Prices Index')
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Average Prices Index')

ax2 = ax.twinx()
ax2.plot(realtional_df.index, realtional_df['GDP_mean'],color='darkgoldenrod',marker='o',label='Average Gross Domastic Product')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Average Gross Domastic Product')
ax2.set_ylim(0, max(realtional_df['GDP_mean'])+1000)

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(20,5))
fig.suptitle('Average Prices Index vs Average Median Sales Price in US Per Years')
ax.bar(realtional_df.index, realtional_df['CSUSHPISA_mean'],color='burlywood',label='Prices Index')
ax.set_xlabel('Time Period (Years)')
ax.set_ylabel('Average Prices Index')

ax2 = ax.twinx()
ax2.plot(realtional_df.index, realtional_df['MSPUS_mean'],color='darkgoldenrod',marker='o',label='Average Median Sales Price')
ax2.set_xlabel('Time Period (Years)')
ax2.set_ylabel('Average Median Sales Price')

fig.legend()
ax.grid(False)
ax2.grid(False)
plt.show()

# %% [markdown]
# ### Observation of Multivariate Analysis
#
# In our analysis, we identified several features that demonstrate a strong relationship with the target column CSUSHPISA:
#
# #### Vacant Housing Units (EVACANTUSQ176N)
# - This feature shows a substantial correlation with CSUSHPISA, suggesting its influence on housing price variations.
#
# #### Gross Domestic Product (GDP)
# - GDP exhibits a significant connection with CSUSHPISA, indicating an impact on housing prices aligned with GDP fluctuations.
#
# #### Median Sales Price (MSPUS)
# - MSPUS demonstrates a robust correlation with CSUSHPISA, suggesting a direct influence on housing price trends.
#
# These features, Vacant Housing Units, Gross Domestic Product, and Median Sales Price, exhibit a noteworthy relationship with the target column CSUSHPISA, emphasizing their relevance in understanding housing price variations.

# %% [markdown]
# ## Feature Transformations

# %% [markdown]
# ### Note: Skewness Interpretation:
#
# 1. **Moderate Skewness:**
#    - Between -0.5 and 0.5 (approximately)
#    - The distribution is moderately skewed but relatively close to a symmetric distribution.
#
# 2. **Good or Acceptable Skewness:**
#    - Between -1 and -0.5 or between 0.5 and 1 (approximately)
#    - Acceptable range for many statistical analyses.
#
# 3. **High or Severe Skewness:**
#    - Less than -1 or greater than 1 (approximately)
#    - Indicates a significantly skewed distribution, possibly needing correction for certain analyses.

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of CSUSHPISA after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['CSUSHPISA'],ax=ax[0][0])
skew = np.round(stats.skew(df['CSUSHPISA']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


sns.distplot(np.log(df['CSUSHPISA']),ax=ax[0][1])
skew = np.round(stats.skew(np.log(df['CSUSHPISA'])),2)
ax[0][1].set_title(f'Log Distribution skew : {skew}')


sns.distplot(np.sqrt(df['CSUSHPISA']),ax=ax[0][2])
skew = np.round(stats.skew(np.sqrt(df['CSUSHPISA'])),2)
ax[0][2].set_title(f'sqrt Distribution skew : {skew}')

sns.boxplot(df['CSUSHPISA'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(np.log(df['CSUSHPISA']),ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Log Distribution')

sns.boxplot(np.sqrt(df['CSUSHPISA']),ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot sqrt Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of EVACANTUSQ176N after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['EVACANTUSQ176N'],ax=ax[0][0])
skew = np.round(stats.skew(df['EVACANTUSQ176N']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


data_boxcox, lambda_boxcox = stats.boxcox(df['EVACANTUSQ176N'])
sns.distplot(data_boxcox,ax=ax[0][1])
skew = np.round(stats.skew(data_boxcox),2)
ax[0][1].set_title(f'Boxcox Distribution skew : {skew}')

data_yeojohnson, lambda_yeojohnson = stats.yeojohnson(df['EVACANTUSQ176N'])
sns.distplot(data_yeojohnson,ax=ax[0][2])
skew = np.round(stats.skew(data_yeojohnson),2)
ax[0][2].set_title(f'Yeojohnson Distribution skew : {skew}')

sns.boxplot(df['EVACANTUSQ176N'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(data_boxcox,ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Boxcox Distribution')

sns.boxplot(data_boxcox,ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot Yeojohnson Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of GDP after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['GDP'],ax=ax[0][0])
skew = np.round(stats.skew(df['GDP']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


data_boxcox, lambda_boxcox = stats.boxcox(df['GDP'])
sns.distplot(data_boxcox,ax=ax[0][1])
skew = np.round(stats.skew(data_boxcox),2)
ax[0][1].set_title(f'Boxcox Distribution skew : {skew}')

data_yeojohnson, lambda_yeojohnson = stats.yeojohnson(df['GDP'])
sns.distplot(data_yeojohnson,ax=ax[0][2])
skew = np.round(stats.skew(data_yeojohnson),2)
ax[0][2].set_title(f'Yeojohnson Distribution skew : {skew}')

sns.boxplot(df['GDP'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(data_boxcox,ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Boxcox Distribution')

sns.boxplot(data_boxcox,ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot Yeojohnson Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of INTDSRUSM193N after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['INTDSRUSM193N'],ax=ax[0][0])
skew = np.round(stats.skew(df['INTDSRUSM193N']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


data_boxcox, lambda_boxcox = stats.boxcox(df['INTDSRUSM193N'])
sns.distplot(data_boxcox,ax=ax[0][1])
skew = np.round(stats.skew(data_boxcox),2)
ax[0][1].set_title(f'Boxcox Distribution skew : {skew}')

data_yeojohnson, lambda_yeojohnson = stats.yeojohnson(df['INTDSRUSM193N'])
sns.distplot(data_yeojohnson,ax=ax[0][2])
skew = np.round(stats.skew(data_yeojohnson),2)
ax[0][2].set_title(f'Yeojohnson Distribution skew : {skew}')

sns.boxplot(df['INTDSRUSM193N'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(data_boxcox,ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Boxcox Distribution')

sns.boxplot(data_boxcox,ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot Yeojohnson Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of MSACSR after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['MSACSR'],ax=ax[0][0])
skew = np.round(stats.skew(df['MSACSR']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


data_boxcox, lambda_boxcox = stats.boxcox(df['MSACSR'])
sns.distplot(data_boxcox,ax=ax[0][1])
skew = np.round(stats.skew(data_boxcox),2)
ax[0][1].set_title(f'Boxcox Distribution skew : {skew}')

data_yeojohnson, lambda_yeojohnson = stats.yeojohnson(df['MSACSR'])
sns.distplot(data_yeojohnson,ax=ax[0][2])
skew = np.round(stats.skew(data_yeojohnson),2)
ax[0][2].set_title(f'Yeojohnson Distribution skew : {skew}')

sns.boxplot(df['MSACSR'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(data_boxcox,ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Boxcox Distribution')

sns.boxplot(data_boxcox,ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot Yeojohnson Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of PERMIT after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['PERMIT'],ax=ax[0][0])
skew = np.round(stats.skew(df['PERMIT']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


data_boxcox, lambda_boxcox = stats.boxcox(df['PERMIT'])
sns.distplot(data_boxcox,ax=ax[0][1])
skew = np.round(stats.skew(data_boxcox),2)
ax[0][1].set_title(f'Boxcox Distribution skew : {skew}')

data_yeojohnson, lambda_yeojohnson = stats.yeojohnson(df['PERMIT'])
sns.distplot(data_yeojohnson,ax=ax[0][2])
skew = np.round(stats.skew(data_yeojohnson),2)
ax[0][2].set_title(f'Yeojohnson Distribution skew : {skew}')

sns.boxplot(df['PERMIT'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(data_boxcox,ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Boxcox Distribution')

sns.boxplot(data_boxcox,ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot Yeojohnson Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of UMCSENT after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['UMCSENT'],ax=ax[0][0])
skew = np.round(stats.skew(df['UMCSENT']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


sns.distplot(np.log(df['UMCSENT']),ax=ax[0][1])
skew = np.round(stats.skew(np.log(df['UMCSENT'])),2)
ax[0][1].set_title(f'Log Distribution skew : {skew}')


sns.distplot(np.sqrt(df['UMCSENT']),ax=ax[0][2])
skew = np.round(stats.skew(np.sqrt(df['UMCSENT'])),2)
ax[0][2].set_title(f'sqrt Distribution skew : {skew}')

sns.boxplot(df['UMCSENT'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(np.log(df['UMCSENT']),ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Log Distribution')

sns.boxplot(np.sqrt(df['CSUSHPISA']),ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot sqrt Distribution')

plt.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(20,10))
fig.suptitle('Distribution of MSPUS after Different Transformations and Boxplots',fontsize=20)
sns.distplot(df['MSPUS'],ax=ax[0][0])
skew = np.round(stats.skew(df['MSPUS']),2)
ax[0][0].set_title(f'Original Distribution skew : {skew}')


sns.distplot(np.log(df['MSPUS']),ax=ax[0][1])
skew = np.round(stats.skew(np.log(df['MSPUS'])),2)
ax[0][1].set_title(f'Log Distribution skew : {skew}')


sns.distplot(np.sqrt(df['MSPUS']),ax=ax[0][2])
skew = np.round(stats.skew(np.sqrt(df['MSPUS'])),2)
ax[0][2].set_title(f'sqrt Distribution skew : {skew}')

sns.boxplot(df['MSPUS'],ax=ax[1][0],orient='h')
ax[1][0].set_title(f'Boxplot Normal Distribution')

sns.boxplot(np.log(df['MSPUS']),ax=ax[1][1],orient='h')
ax[1][1].set_title(f'Boxplot Log Distribution')

sns.boxplot(np.sqrt(df['CSUSHPISA']),ax=ax[1][2],orient='h')
ax[1][2].set_title(f'Boxplot sqrt Distribution')

plt.show()

# %% [markdown]
# ### Observation Of Feature Transformation
#
# - CSUSHPISA lOG,BOXCOX (EXTREME VALUE HANDLED)
# - EVACANTUSQ176N either BOXCOX or YEOJOHNSON
# - GDP SQRT, BOXCOX or YEOJOHSON
# - INTDSRUSM193N LOG, BOXCOX or YEOJOHNSON (EXTREME VALUE HANDLED)
# - MSACSR BOXCOX is better performing than YEOJOHSON (EXTREME VALUE HANDLED)
# - PERMIT LOG, BOXCOX or YEOJOHNSON
# - UMCSENT BOXCOX or YEOJOHNSON
# - MSPUS LOG or BOXCOX
#
#
# NOTE: We BOXCOX is better performer if we measure using skewness for all feature giving better result (Closed to Normal Distribution)
